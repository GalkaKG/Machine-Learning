# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pickle

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, FunctionTransformer

from sklearn.linear_model import LogisticRegression, LinearRegression, Lasso, Ridge, ElasticNet

from sklearn.model_selection import train_test_split

# %% [markdown]
# # Model Training and Improvement

# %%
# epssilon
EPS = 1e-10

# %%
diabetes_data = pd.read_csv("data/diabetic_data.csv")

# %%
diabetes_data.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
diabetes_data.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
diabetes_data.columns[diabetes_data.columns.str.contains("_id")]
# Out:
# Index(['encounter_id', 'admission_type_id', 'discharge_disposition_id',
#        'admission_source_id'],
#       dtype='object')

# %%
diabetes_data.pioglitazone.unique()
# Out:
# array(['No', 'Steady', 'Up', 'Down'], dtype=object)

# %%
diabetes_data.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# examide                     object
# citoglipton                 object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                  object
# dtype: object

# %%
pd.get_dummies(diabetes_data, drop_first = True).dtypes
# Out:
# encounter_id                     int64
# patient_nbr                      int64
# admission_type_id                int64
# discharge_disposition_id         int64
# admission_source_id              int64
#                                  ...
# metformin-pioglitazone_Steady    uint8
# change_No                        uint8
# diabetesMed_Yes                  uint8
# readmitted_>30                   uint8
# readmitted_NO                    uint8
# Length: 2438, dtype: object

# %%
diabetes_attributes = diabetes_data.drop(columns = "readmitted")
diabetes_target = diabetes_data.readmitted

# %%
diabetes_attributes_dummies = pd.get_dummies(diabetes_attributes)

# %%
logistic_regression = LogisticRegression()

# %%
logistic_regression.fit(diabetes_attributes_dummies, diabetes_target)
# Out:
# LogisticRegression()

# %%
logistic_regression.coef_
# Out:
# array([[-1.96952335e-09, -2.05892693e-09, -4.34014319e-04, ...,
#         -1.24877634e-04, -6.27839232e-05, -1.13112782e-04],
#        [-2.92053042e-10,  4.61961230e-09, -8.83494551e-05, ...,
#         -5.14875620e-05, -4.74378759e-05,  2.31595662e-05],
#        [ 2.29806616e-09, -2.56065263e-09,  5.22363774e-04, ...,
#          1.76365196e-04,  1.10221799e-04,  8.99532157e-05]])

# %% [markdown]
# __Да закачим цялята обработка на данните към модела и да я експортна заедно с него. Това са sklearn pipelines.__

# %%
scaler = MinMaxScaler()

# %%
diabetes_attributes_scaled = scaler.fit_transform(diabetes_attributes_dummies)

# %%
logistic_regression.fit(diabetes_attributes_scaled, diabetes_target)
# Out:
# C:\Users\galin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logistic_regression.score(diabetes_attributes_scaled, diabetes_target)
# Out:
# 0.5950317394807696

# %%
logistic_regression.score(diabetes_attributes_dummies, diabetes_target)
# Out:
# C:\Users\galin\anaconda3\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# 0.5395908260126172

# %%
pipeline = Pipeline([
    ("scaler", MinMaxScaler()),
    ("model", LogisticRegression())
])

# %%
pipeline
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('model', LogisticRegression())])

# %%
sample_data = diabetes_data.sample(5000, random_state=42)

# %%
sample_data
# Out:
#        encounter_id  patient_nbr             race  gender      age weight  \
# 35956     110939484     19274094        Caucasian  Female  [70-80)      ?
# 60927     170328306     65634327        Caucasian    Male  [50-60)      ?
# 79920     245688426    100657359        Caucasian  Female  [60-70)      ?
# 50078     150826224     83144448        Caucasian    Male  [30-40)      ?
# 44080     135993852     65234214  AfricanAmerican  Female  [60-70)      ?
# ...             ...          ...              ...     ...      ...    ...
# 35562     110096790     33502212        Caucasian    Male  [50-60)      ?
# 98563     402583472    141357506  AfricanAmerican    Male  [50-60)      ?
# 88066     282442506     45759951        Caucasian  Female  [40-50)      ?
# 55955     161139018    112510251        Caucasian  Female  [40-50)      ?
# 31470     100977444     98312472        Caucasian  Female  [70-80)      ?
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 35956                  1                         1                    6
# 60927                  1                         1                    1
# 79920                  3                         6                    1
# 50078                  2                         1                    1
# 44080                  1                         2                    7
# ...                  ...                       ...                  ...
# 35562                  6                         1                    7
# 98563                  7                         3                    7
# 88066                  1                         1                    7
# 55955                  5                         1                    1
# 31470                  6                         1                   17
#
#        time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 35956                11  ...          No  Steady                   No
# 60927                 1  ...          No      No                   No
# 79920                 4  ...          No      No                   No
# 50078                12  ...          No      No                   No
# 44080                 1  ...          No      No                   No
# ...                 ...  ...         ...     ...                  ...
# 35562                12  ...          No    Down                   No
# 98563                 6  ...          No  Steady                   No
# 88066                 3  ...          No      No                   No
# 55955                 3  ...          No      Up                   No
# 31470                 5  ...          No      No                   No
#
#        glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 35956                   No                        No                       No
# 60927                   No                        No                       No
# 79920                   No                        No                       No
# 50078                   No                        No                       No
# 44080                   No                        No                       No
# ...                    ...                       ...                      ...
# 35562                   No                        No                       No
# 98563                   No                        No                       No
# 88066                   No                        No                       No
# 55955                   No                        No                       No
# 31470                   No                        No                       No
#
#        metformin-pioglitazone  change diabetesMed readmitted
# 35956                      No      No         Yes         NO
# 60927                      No      No         Yes         NO
# 79920                      No      No         Yes         NO
# 50078                      No      No         Yes        >30
# 44080                      No      No         Yes        <30
# ...                       ...     ...         ...        ...
# 35562                      No      Ch         Yes         NO
# 98563                      No      No         Yes         NO
# 88066                      No      No         Yes         NO
# 55955                      No      Ch         Yes         NO
# 31470                      No      No          No        >30
#
# [5000 rows x 50 columns]

# %%
sample_attributes = sample_data.drop(columns = "readmitted")

# %%
sample_target = sample_data.readmitted

# %%
sample_attributes = pd.get_dummies(sample_attributes)

# %%
pipeline.fit(sample_attributes, sample_target)
# Out:
# C:\Users\galin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('scaler', MinMaxScaler()), ('model', LogisticRegression())])

# %%
ohe = OneHotEncoder()

# %%
ohe.fit(sample_attributes)
# Out:
# OneHotEncoder()

# %%
ohe.feature_names_in_
# Out:
# array(['encounter_id', 'patient_nbr', 'admission_type_id', ...,
#        'change_No', 'diabetesMed_No', 'diabetesMed_Yes'], dtype=object)

# %%
# ohe.categories_

# %%
sample_data.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
categorical_columns = sample_data.dtypes[sample_data.dtypes == np.object_].index.values

# %%
categorical_columns = categorical_columns[:-1]

# %%
sample_data.dtypes[sample_data.dtypes != np.object_].index.values[2:]
# Out:
# array(['admission_type_id', 'discharge_disposition_id',
#        'admission_source_id', 'time_in_hospital', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'number_diagnoses'],
#       dtype=object)

# %%
numerical_columns = [
    'admission_type_id', 'discharge_disposition_id',
    'time_in_hospital', 'num_lab_procedures',
    'num_procedures', 'num_medications', 'number_outpatient',
    'number_emergency', 'number_inpatient', 'number_diagnoses'
]

# %%
categorical = ColumnTransformer([
    ("categorical", OneHotEncoder(), categorical_columns),
    ("numerical", MinMaxScaler(), numerical_columns)
], remainder = "passtrought")

# %%
categorical
# Out:
# ColumnTransformer(remainder='passtrought',
#                   transformers=[('categorical', OneHotEncoder(),
#                                  array(['race', 'gender', 'age', 'weight', 'payer_code',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'pioglitazon...
#        'glipizide-metformin', 'glimepiride-pioglitazone',
#        'metformin-rosiglitazone', 'metformin-pioglitazone', 'change',
#        'diabetesMed'], dtype=object)),
#                                 ('numerical', MinMaxScaler(),
#                                  ['admission_type_id',
#                                   'discharge_disposition_id',
#                                   'time_in_hospital', 'num_lab_procedures',
#                                   'num_procedures', 'num_medications',
#                                   'number_outpatient', 'number_emergency',
#                                   'number_inpatient', 'number_diagnoses'])])

# %%
FunctionTransformer(np.log10).transform(sample_attributes[numerical_columns])
# Out:
# C:\Users\galin\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = func(self.values, **kwargs)
#        admission_type_id  discharge_disposition_id  time_in_hospital  \
# 35956           0.000000                  0.000000          1.041393
# 60927           0.000000                  0.000000          0.000000
# 79920           0.477121                  0.778151          0.602060
# 50078           0.301030                  0.000000          1.079181
# 44080           0.000000                  0.301030          0.000000
# ...                  ...                       ...               ...
# 35562           0.778151                  0.000000          1.079181
# 98563           0.845098                  0.477121          0.778151
# 88066           0.000000                  0.000000          0.477121
# 55955           0.698970                  0.000000          0.477121
# 31470           0.778151                  0.000000          0.698970
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# 35956            1.832509            -inf         1.301030               -inf
# 60927            1.301030            -inf         0.845098               -inf
# 79920            1.322219        0.477121         1.361728                0.0
# 50078            1.447158            -inf         1.278754               -inf
# 44080            1.322219            -inf         0.778151               -inf
# ...                   ...             ...              ...                ...
# 35562            1.812913        0.301030         1.278754               -inf
# 98563            1.785330        0.000000         1.146128               -inf
# 88066            1.447158        0.778151         0.778151               -inf
# 55955            1.431364            -inf         1.000000                0.0
# 31470            1.431364        0.301030         1.041393               -inf
#
#        number_emergency  number_inpatient  number_diagnoses
# 35956              -inf              -inf          0.698970
# 60927              -inf              -inf          0.903090
# 79920              -inf           0.30103          0.845098
# 50078              -inf           0.00000          0.845098
# 44080              -inf              -inf          0.845098
# ...                 ...               ...               ...
# 35562              -inf              -inf          0.954243
# 98563              -inf              -inf          0.954243
# 88066              -inf              -inf          0.477121
# 55955               0.0           0.00000          0.903090
# 31470              -inf              -inf          0.845098
#
# [5000 rows x 10 columns]

# %%
log_scaler = FunctionTransformer(lambda x: np.log10(x + EPS))

# %%
number_processor = Pipeline([
    ("log_transformer", FunctionTransformer(np.log10)),
    ("minmax", MinMaxScaler())
])

# %%
number_processor
# Out:
# Pipeline(steps=[('log_transformer', FunctionTransformer(func=<ufunc 'log10'>)),
#                 ('minmax', MinMaxScaler())])

# %%
preprocessor = ColumnTransformer([
    ("categorical", OneHotEncoder(), categorical_columns),
    ("numerical", MinMaxScaler(), numerical_columns)
], remainder = "drop")

# %%
pipeline = Pipeline([
    ("preprocess", preprocessor),
    ("classifies", LogisticRegression())
])

# %% [markdown]
# pipeline e estimator.

# %%
pipeline.steps
# Out:
# [('preprocess',
#   ColumnTransformer(transformers=[('categorical', OneHotEncoder(),
#                                    array(['race', 'gender', 'age', 'weight', 'payer_code',
#          'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#          'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#          'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#          'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone',
#          'acar...
#          'glipizide-metformin', 'glimepiride-pioglitazone',
#          'metformin-rosiglitazone', 'metformin-pioglitazone', 'change',
#          'diabetesMed'], dtype=object)),
#                                   ('numerical', MinMaxScaler(),
#                                    ['admission_type_id',
#                                     'discharge_disposition_id',
#                                     'time_in_hospital', 'num_lab_procedures',
#                                     'num_procedures', 'num_medications',
#                                     'number_outpatient', 'number_emergency',
#                                     'number_inpatient', 'number_diagnoses'])])),
#  ('classifies', LogisticRegression())]

# %%
samples_attributes = sample_data.drop(columns = "readmitted")
sample_target = sample_data.readmitted

# %%
np.log10(0 + 1e-6)
# Out:
# -6.0

# %%
# pipeline.fit(sample_attributes, sample_target)

# %%
# pipeline.score(sample_attributes, sample_target)

# %% [markdown]
# ### Така се запазва модел да живее в рам паметта на компютъра:

# %%
pickle.dump(pipeline, open("prediction_pipeline.pkl", "wb"))

# %%
pickle.dump(logistic_regression, open("prediction_log_regression.pkl", "wb"))

# %%
model = pickle.load(open("prediction_log_regression.pkl", "rb"))

# %%
model.coef_
# Out:
# array([[-0.19861529,  0.14901103, -0.12530781, ..., -0.02687513,
#         -0.10804452,  0.0203764 ],
#        [-0.71627926,  0.57149708,  0.16718931, ..., -0.00600077,
#         -0.03499498,  0.03864166],
#        [ 0.91489454, -0.72050811, -0.0418815 , ...,  0.0328759 ,
#          0.14303949, -0.05901806]])

# %%
pipeline.steps[0][1].feature_names_in_
# Out:
# array(['encounter_id', 'patient_nbr', 'admission_type_id', ...,
#        'change_No', 'diabetesMed_No', 'diabetesMed_Yes'], dtype=object)

# %%
pipeline.steps[0][1]
# Out:
# ColumnTransformer(transformers=[('categorical', OneHotEncoder(),
#                                  array(['race', 'gender', 'age', 'weight', 'payer_code',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone',
#        'acar...
#        'glipizide-metformin', 'glimepiride-pioglitazone',
#        'metformin-rosiglitazone', 'metformin-pioglitazone', 'change',
#        'diabetesMed'], dtype=object)),
#                                 ('numerical', MinMaxScaler(),
#                                  ['admission_type_id',
#                                   'discharge_disposition_id',
#                                   'time_in_hospital', 'num_lab_procedures',
#                                   'num_procedures', 'num_medications',
#                                   'number_outpatient', 'number_emergency',
#                                   'number_inpatient', 'number_diagnoses'])])

# %%
diabetes_data = pd.read_csv("data/diabetic_data.csv")

# %%
sample_data = diabetes_data.sample(5000, random_state = 12341234)
attributes = sample_data.drop(columns = ["readmitted"])
target = sample_data.readmitted

# %%
pipeline.fit(attributes, target)
# Out:
# C:\Users\galin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   OneHotEncoder(),
#                                                   array(['race', 'gender', 'age', 'weight', 'payer_code',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'piogl...
#        'metformin-rosiglitazone', 'metformin-pioglitazone', 'change',
#        'diabetesMed'], dtype=object)),
#                                                  ('numerical', MinMaxScaler(),
#                                                   ['admission_type_id',
#                                                    'discharge_disposition_id',
#                                                    'time_in_hospital',
#                                                    'num_lab_procedures',
#                                                    'num_procedures',
#                                                    'num_medications',
#                                                    'number_outpatient',
#                                                    'number_emergency',
#                                                    'number_inpatient',
#                                                    'number_diagnoses'])])),
#                 ('classifies', LogisticRegression())])

# %% [markdown]
# variance - са външни фактори.
#
# Най-просто казано __high bias__ има алгоритъм дори данните, които сме му показали. Очакваме да се справи по-добре на тях и той още бърка.
#
# __High variance__ познава данните добре, но е хаотичен.

# %%
LogisticRegression(penalty = None)
# Out:
# LogisticRegression(penalty=None)

# %% [markdown]
# Това означава "не прави регуляризация - дай ми най-добрата Логистична регресия спрямо данните и толкова".

# %%
# pipeline["classifier"]

# %%
pipeline_reg = Pipeline([
    ("preprocess", preprocessor),
    ("classifier", LogisticRegression(C = 0.00001))
])

# %%
pipeline_reg.fit(attributes, target)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   OneHotEncoder(),
#                                                   array(['race', 'gender', 'age', 'weight', 'payer_code',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'piogl...
#        'metformin-rosiglitazone', 'metformin-pioglitazone', 'change',
#        'diabetesMed'], dtype=object)),
#                                                  ('numerical', MinMaxScaler(),
#                                                   ['admission_type_id',
#                                                    'discharge_disposition_id',
#                                                    'time_in_hospital',
#                                                    'num_lab_procedures',
#                                                    'num_procedures',
#                                                    'num_medications',
#                                                    'number_outpatient',
#                                                    'number_emergency',
#                                                    'number_inpatient',
#                                                    'number_diagnoses'])])),
#                 ('classifier', LogisticRegression(C=1e-05))])

# %%
pipeline_reg["classifier"]
# Out:
# LogisticRegression(C=1e-05)

# %%
pipeline_reg["classifier"].coef_
# Out:
# array([[-7.66935212e-05,  7.27091746e-05, -1.76754480e-05, ...,
#          1.05076097e-05,  1.94479419e-04,  1.69803716e-04],
#        [-5.98065573e-05, -1.51015287e-04, -1.72957678e-05, ...,
#          3.21245871e-05,  1.92212849e-04,  3.09161094e-04],
#        [ 1.36500078e-04,  7.83061121e-05,  3.49712158e-05, ...,
#         -4.26321968e-05, -3.86692268e-04, -4.78964810e-04]])

# %%
train_test_split(attributes)
# Out:
# [       encounter_id  patient_nbr             race  gender      age weight  \
#  2040       13164612    101742885        Caucasian  Female  [60-70)      ?
#  70512     202473858    110632374        Caucasian  Female  [70-80)      ?
#  46665     143832654     95469183  AfricanAmerican  Female  [50-60)      ?
#  56494     162183894     88343514        Caucasian  Female  [70-80)      ?
#  82871     258651486     46499625        Caucasian    Male  [60-70)      ?
#  ...             ...          ...              ...     ...      ...    ...
#  15270      58814274     19154979        Caucasian  Female  [10-20)      ?
#  97516     389623508     41965398        Caucasian  Female  [70-80)      ?
#  48554     147972978     37346643        Caucasian    Male  [60-70)      ?
#  83820     263110470     63125073        Caucasian    Male  [40-50)      ?
#  47560     146038230     42339753        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
#  2040                   2                         1                    2
#  70512                  3                         1                    1
#  46665                  2                         8                    1
#  56494                  5                         6                    1
#  82871                  3                         1                    1
#  ...                  ...                       ...                  ...
#  15270                  3                         1                    1
#  97516                  3                         1                    1
#  48554                  3                         1                    1
#  83820                  6                         6                   17
#  47560                  3                         6                    1
#
#         time_in_hospital  ... examide citoglipton  insulin  \
#  2040                  5  ...      No          No     Down
#  70512                 1  ...      No          No   Steady
#  46665                 3  ...      No          No       Up
#  56494                 6  ...      No          No       No
#  82871                 1  ...      No          No       No
#  ...                 ...  ...     ...         ...      ...
#  15270                 2  ...      No          No   Steady
#  97516                 1  ...      No          No       No
#  48554                 1  ...      No          No   Steady
#  83820                 5  ...      No          No       Up
#  47560                 4  ...      No          No       No
#
#         glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
#  2040                    No                   No                        No
#  70512                   No                   No                        No
#  46665                   No                   No                        No
#  56494                   No                   No                        No
#  82871                   No                   No                        No
#  ...                    ...                  ...                       ...
#  15270                   No                   No                        No
#  97516                   No                   No                        No
#  48554                   No                   No                        No
#  83820                   No                   No                        No
#  47560                   No                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone change diabetesMed
#  2040                        No                      No     Ch         Yes
#  70512                       No                      No     No         Yes
#  46665                       No                      No     Ch         Yes
#  56494                       No                      No     Ch         Yes
#  82871                       No                      No     No         Yes
#  ...                        ...                     ...    ...         ...
#  15270                       No                      No     No         Yes
#  97516                       No                      No     No          No
#  48554                       No                      No     No         Yes
#  83820                       No                      No     Ch         Yes
#  47560                       No                      No     No         Yes
#
#  [3750 rows x 49 columns],
#          encounter_id  patient_nbr             race  gender       age weight  \
#  58667      165995346     42966720        Caucasian    Male   [30-40)      ?
#  23218       79384050       906471        Caucasian    Male   [70-80)      ?
#  34722      108342270     33103440         Hispanic    Male   [60-70)      ?
#  70201      200986752     27901341        Caucasian    Male   [80-90)      ?
#  101244     436750646    125919338        Caucasian    Male  [90-100)      ?
#  ...              ...          ...              ...     ...       ...    ...
#  40696      126281814     35472969        Caucasian  Female   [80-90)      ?
#  45443      140445882     95346513  AfricanAmerican  Female   [60-70)      ?
#  66481      185631774     33923565  AfricanAmerican  Female   [50-60)      ?
#  60571      169563486     67575411        Caucasian  Female   [80-90)      ?
#  12528       50840328      2717082  AfricanAmerican  Female   [70-80)      ?
#
#          admission_type_id  discharge_disposition_id  admission_source_id  \
#  58667                   3                         1                    1
#  23218                   1                         1                    7
#  34722                   3                         1                    1
#  70201                   3                         1                    1
#  101244                  1                         1                    7
#  ...                   ...                       ...                  ...
#  40696                   2                         3                    7
#  45443                   1                         7                    7
#  66481                   2                         1                    7
#  60571                   1                         6                    7
#  12528                   1                        18                    7
#
#          time_in_hospital  ... examide citoglipton  insulin  \
#  58667                  4  ...      No          No     Down
#  23218                  4  ...      No          No   Steady
#  34722                  3  ...      No          No       No
#  70201                  1  ...      No          No       No
#  101244                 2  ...      No          No       No
#  ...                  ...  ...     ...         ...      ...
#  40696                  3  ...      No          No     Down
#  45443                  1  ...      No          No   Steady
#  66481                  4  ...      No          No     Down
#  60571                  6  ...      No          No       No
#  12528                  6  ...      No          No       No
#
#          glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
#  58667                    No                   No                        No
#  23218                    No                   No                        No
#  34722                Steady                   No                        No
#  70201                    No                   No                        No
#  101244                   No                   No                        No
#  ...                     ...                  ...                       ...
#  40696                    No                   No                        No
#  45443                    No                   No                        No
#  66481                    No                   No                        No
#  60571                    No                   No                        No
#  12528                    No                   No                        No
#
#          metformin-rosiglitazone  metformin-pioglitazone change diabetesMed
#  58667                        No                      No     Ch         Yes
#  23218                        No                      No     Ch         Yes
#  34722                        No                      No     Ch         Yes
#  70201                        No                      No     No          No
#  101244                       No                      No     No         Yes
#  ...                         ...                     ...    ...         ...
#  40696                        No                      No     Ch         Yes
#  45443                        No                      No     No         Yes
#  66481                        No                      No     Ch         Yes
#  60571                        No                      No     No         Yes
#  12528                        No                      No     No         Yes
#
#  [1250 rows x 49 columns]]

# %%
len(train_test_split(attributes))
# Out:
# 2

# %%
train_test_split(attributes)[0]
# Out:
#        encounter_id  patient_nbr             race  gender      age   weight  \
# 14661      56950398     24945534  AfricanAmerican  Female  [40-50)        ?
# 14966      57809472     37599057                ?  Female  [40-50)  [50-75)
# 94206     345434114     85088421        Caucasian  Female  [40-50)        ?
# 91655     312015170     95036895        Caucasian  Female  [80-90)        ?
# 37677     116989524     39240927        Caucasian  Female  [60-70)        ?
# ...             ...          ...              ...     ...      ...      ...
# 17457      64228014       346374        Caucasian  Female  [50-60)        ?
# 90743     300135980    177164771        Caucasian  Female  [70-80)        ?
# 70797     203873310     41777082        Caucasian  Female  [40-50)        ?
# 81605     253126260     85119066        Caucasian  Female  [70-80)        ?
# 20599      72498378     37953729        Caucasian    Male  [70-80)        ?
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 14661                  5                        16                   17
# 14966                  6                         1                   17
# 94206                  1                         1                    7
# 91655                  1                         6                    7
# 37677                  6                         1                    7
# ...                  ...                       ...                  ...
# 17457                  2                         1                    1
# 90743                  1                         6                    7
# 70797                  1                         1                    7
# 81605                  1                         2                    1
# 20599                  1                         1                    7
#
#        time_in_hospital  ... examide citoglipton  insulin  \
# 14661                 3  ...      No          No       No
# 14966                 1  ...      No          No       No
# 94206                 5  ...      No          No       Up
# 91655                 2  ...      No          No   Steady
# 37677                 1  ...      No          No       No
# ...                 ...  ...     ...         ...      ...
# 17457                 2  ...      No          No   Steady
# 90743                 8  ...      No          No   Steady
# 70797                 7  ...      No          No     Down
# 81605                 2  ...      No          No   Steady
# 20599                 6  ...      No          No       No
#
#        glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 14661                   No                   No                        No
# 14966                   No                   No                        No
# 94206                   No                   No                        No
# 91655                   No                   No                        No
# 37677                   No                   No                        No
# ...                    ...                  ...                       ...
# 17457                   No                   No                        No
# 90743                   No                   No                        No
# 70797                   No                   No                        No
# 81605                   No                   No                        No
# 20599                   No                   No                        No
#
#        metformin-rosiglitazone  metformin-pioglitazone change diabetesMed
# 14661                       No                      No     No         Yes
# 14966                       No                      No     No          No
# 94206                       No                      No     Ch         Yes
# 91655                       No                      No     Ch         Yes
# 37677                       No                      No     No          No
# ...                        ...                     ...    ...         ...
# 17457                       No                      No     No         Yes
# 90743                       No                      No     Ch         Yes
# 70797                       No                      No     Ch         Yes
# 81605                       No                      No     No         Yes
# 20599                       No                      No     No         Yes
#
# [3750 rows x 49 columns]

# %%
train_test_split(attributes)[1]
# Out:
#        encounter_id  patient_nbr       race  gender      age weight  \
# 31953     102259950      8715474  Caucasian  Female  [70-80)      ?
# 84321     265550274     43814007  Caucasian  Female  [40-50)      ?
# 14096      55308840     82976310  Caucasian    Male  [70-80)      ?
# 16882      62781276       360576  Caucasian  Female  [70-80)      ?
# 32173     102769944      3424896  Caucasian    Male  [70-80)      ?
# ...             ...          ...        ...     ...      ...    ...
# 63166     175632468     23194305  Caucasian  Female  [70-80)      ?
# 40937     126928062     78381549  Caucasian    Male  [60-70)      ?
# 82132     255543948     56124891  Caucasian    Male  [70-80)      ?
# 21143      73832160     23641785  Caucasian  Female  [40-50)      ?
# 44618     137650122    100918386  Caucasian  Female  [80-90)      ?
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 31953                  1                         1                    6
# 84321                  1                         1                    7
# 14096                  1                         3                    7
# 16882                  1                        18                    7
# 32173                  1                         1                    6
# ...                  ...                       ...                  ...
# 63166                  1                         6                    7
# 40937                  2                         3                    1
# 82132                  1                        11                    7
# 21143                  5                         1                   17
# 44618                  2                         1                    7
#
#        time_in_hospital  ... examide citoglipton  insulin  \
# 31953                 2  ...      No          No       No
# 84321                 2  ...      No          No       No
# 14096                 5  ...      No          No   Steady
# 16882                 2  ...      No          No       No
# 32173                 1  ...      No          No       No
# ...                 ...  ...     ...         ...      ...
# 63166                 7  ...      No          No       Up
# 40937                10  ...      No          No     Down
# 82132                13  ...      No          No       Up
# 21143                 4  ...      No          No   Steady
# 44618                 3  ...      No          No       No
#
#        glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 31953                   No                   No                        No
# 84321                   No                   No                        No
# 14096                   No                   No                        No
# 16882                   No                   No                        No
# 32173                   No                   No                        No
# ...                    ...                  ...                       ...
# 63166                   No                   No                        No
# 40937                   No                   No                        No
# 82132                   No                   No                        No
# 21143                   No                   No                        No
# 44618                   No                   No                        No
#
#        metformin-rosiglitazone  metformin-pioglitazone change diabetesMed
# 31953                       No                      No     No         Yes
# 84321                       No                      No     No          No
# 14096                       No                      No     No         Yes
# 16882                       No                      No     No          No
# 32173                       No                      No     No         Yes
# ...                        ...                     ...    ...         ...
# 63166                       No                      No     Ch         Yes
# 40937                       No                      No     Ch         Yes
# 82132                       No                      No     Ch         Yes
# 21143                       No                      No     No         Yes
# 44618                       No                      No     No          No
#
# [1250 rows x 49 columns]

# %% [markdown]
# А така не се разбъркват, с параметър shuffle:

# %%
train_test_split(attributes, shuffle = False)
# Out:
# [       encounter_id  patient_nbr             race  gender      age weight  \
#  38876     120941982    103612347        Caucasian    Male  [70-80)      ?
#  5922       30049656       497178        Caucasian  Female  [60-70)      ?
#  14786      57265020      3545334        Caucasian    Male  [70-80)      ?
#  57920     164717664     86974983  AfricanAmerican  Female  [40-50)      ?
#  40382     125426058     42484968        Caucasian  Female  [80-90)      ?
#  ...             ...          ...              ...     ...      ...    ...
#  63028     175373706     85067748  AfricanAmerican  Female  [50-60)      ?
#  16037      60670074     20238165        Caucasian  Female  [30-40)      ?
#  2701       17326752      1876941        Caucasian    Male  [80-90)      ?
#  86635     275669814     54822699        Caucasian    Male  [60-70)      ?
#  97900     394285754     41655591  AfricanAmerican  Female  [50-60)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
#  38876                  2                         6                    1
#  5922                   1                         1                    7
#  14786                  1                        18                    7
#  57920                  1                         6                    7
#  40382                  3                         3                    1
#  ...                  ...                       ...                  ...
#  63028                  5                         1                    1
#  16037                  2                        18                    4
#  2701                   2                         1                   20
#  86635                  1                         1                    7
#  97900                  1                         1                    7
#
#         time_in_hospital  ... examide citoglipton  insulin  \
#  38876                 5  ...      No          No   Steady
#  5922                  2  ...      No          No       No
#  14786                 4  ...      No          No       No
#  57920                13  ...      No          No       No
#  40382                 8  ...      No          No   Steady
#  ...                 ...  ...     ...         ...      ...
#  63028                 3  ...      No          No   Steady
#  16037                 3  ...      No          No   Steady
#  2701                  1  ...      No          No   Steady
#  86635                 5  ...      No          No     Down
#  97900                 8  ...      No          No       No
#
#         glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
#  38876                   No                   No                        No
#  5922                    No                   No                        No
#  14786                   No                   No                        No
#  57920                   No                   No                        No
#  40382                   No                   No                        No
#  ...                    ...                  ...                       ...
#  63028                   No                   No                        No
#  16037                   No                   No                        No
#  2701                    No                   No                        No
#  86635                   No                   No                        No
#  97900                   No                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone change diabetesMed
#  38876                       No                      No     Ch         Yes
#  5922                        No                      No     Ch         Yes
#  14786                       No                      No     No         Yes
#  57920                       No                      No     No         Yes
#  40382                       No                      No     Ch         Yes
#  ...                        ...                     ...    ...         ...
#  63028                       No                      No     No         Yes
#  16037                       No                      No     No         Yes
#  2701                        No                      No     Ch         Yes
#  86635                       No                      No     Ch         Yes
#  97900                       No                      No     No          No
#
#  [3750 rows x 49 columns],
#         encounter_id  patient_nbr             race  gender       age weight  \
#  59425     167227050     41430294        Caucasian    Male   [50-60)      ?
#  24577      83156082      2770992        Caucasian  Female   [70-80)      ?
#  10802      45370650     23662773        Caucasian  Female   [70-80)      ?
#  29140      95314914     23554800        Caucasian  Female   [60-70)      ?
#  28888      94638660     69426198        Caucasian    Male   [70-80)      ?
#  ...             ...          ...              ...     ...       ...    ...
#  38439     119526228     24924942  AfricanAmerican  Female  [90-100)      ?
#  16200      61121562     19136646        Caucasian  Female   [70-80)      ?
#  17536      64455300     18869373        Caucasian    Male   [60-70)      ?
#  54308     158286690    101859561  AfricanAmerican  Female   [30-40)      ?
#  85601     271350144     77429322        Caucasian  Female   [80-90)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
#  59425                  3                         3                    1
#  24577                  1                         3                    7
#  10802                  1                         3                   17
#  29140                  1                         6                   17
#  28888                  1                         1                    1
#  ...                  ...                       ...                  ...
#  38439                  2                         3                    5
#  16200                  1                        18                    7
#  17536                  1                         1                    7
#  54308                  1                         1                    2
#  85601                  1                         3                    7
#
#         time_in_hospital  ... examide citoglipton  insulin  \
#  59425                 6  ...      No          No     Down
#  24577                 6  ...      No          No   Steady
#  10802                 7  ...      No          No     Down
#  29140                 2  ...      No          No       Up
#  28888                 2  ...      No          No   Steady
#  ...                 ...  ...     ...         ...      ...
#  38439                 5  ...      No          No       No
#  16200                 1  ...      No          No       No
#  17536                 5  ...      No          No     Down
#  54308                 4  ...      No          No   Steady
#  85601                 6  ...      No          No       Up
#
#         glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
#  59425                   No                   No                        No
#  24577                   No                   No                        No
#  10802                   No                   No                        No
#  29140                   No                   No                        No
#  28888                   No                   No                        No
#  ...                    ...                  ...                       ...
#  38439                   No                   No                        No
#  16200                   No                   No                        No
#  17536                   No                   No                        No
#  54308                   No                   No                        No
#  85601                   No                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone change diabetesMed
#  59425                       No                      No     Ch         Yes
#  24577                       No                      No     Ch         Yes
#  10802                       No                      No     Ch         Yes
#  29140                       No                      No     Ch         Yes
#  28888                       No                      No     No         Yes
#  ...                        ...                     ...    ...         ...
#  38439                       No                      No     No          No
#  16200                       No                      No     Ch         Yes
#  17536                       No                      No     Ch         Yes
#  54308                       No                      No     No         Yes
#  85601                       No                      No     Ch         Yes
#
#  [1250 rows x 49 columns]]

# %%
attributes_train, attributes_test, target_train, target_test = train_test_split(attributes, target, test_size = 1000)

# %%
attributes_train.shape, attributes_test.shape, target_train.shape, target_test.shape
# Out:
# ((4000, 49), (1000, 49), (4000,), (1000,))

# %% [markdown]
# 10% от данните за тестване:

# %%
attributes_train, attributes_test, target_train, target_test = train_test_split(
    attributes, target, test_size = 0.1, stratify = target
)

# %%
attributes_train.shape, attributes_test.shape, target_train.shape, target_test.shape
# Out:
# ((4500, 49), (500, 49), (4500,), (500,))

# %%
target.value_counts(normalize = True)
# Out:
# NO     0.5576
# >30    0.3360
# <30    0.1064
# Name: readmitted, dtype: float64

# %%
target_train.value_counts(normalize = True)
# Out:
# NO     0.557556
# >30    0.336000
# <30    0.106444
# Name: readmitted, dtype: float64

# %%
target_test.value_counts(normalize = True)
# Out:
# NO     0.558
# >30    0.336
# <30    0.106
# Name: readmitted, dtype: float64
